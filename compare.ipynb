# %% [markdown]
# ### Observed Results
# **From scratch**
# - MSE: 1760.698475359964
# - RMSE: 41.96067772760545
# - R2 score: 0.9884383081799657
#
# **From sklearn**
# - MSE: 1756.568444900173
# - RMSE: 41.91143572940651
# - R2 score: 0.9884654281781095
#
# ### Why they are almost the same
# - both models are linear regression on the exact same engineered features and same train/validation split.
# - both use the same normalization values (`mu`, `sigma`) from the training data.
# - my from-scratch gradient descent has converged very close to sklearn’s optimal solution.
# - tiny differences are normal because sklearn solves using a deterministic optimized solver, while my scratch model reaches an approximate solution based on learning rate and iterations.
#
# so these close numbers are actually a good sign: my from-scratch implementation is working correctly.
